# %% [markdown]
# # SatRL 1-Million Step Cloud Training (GitHub Workflow)
# This notebook clones/pulls the latest codebase from GitHub and runs training directly in Google Colab without uploading zip files.

# %%
# 1. Fetch latest code from GitHub
import os, shutil
REPO_URL = 'https://github.com/yp2505/spacetech.git'
TARGET_DIR = '/content/spacetech'

# If directory is missing or not a git repository (e.g. old zip extraction), clone fresh
if not os.path.exists(os.path.join(TARGET_DIR, '.git')):
    if os.path.exists(TARGET_DIR):
        shutil.rmtree(TARGET_DIR)
    # !git clone {REPO_URL} {TARGET_DIR}

# %cd {TARGET_DIR}
# !git reset --hard origin/main
# !git pull origin main
print("Current Directory:", os.getcwd())

# %%
# 2. Install Dependencies
# !pip install torch stable-baselines3 shimmy numpy matplotlib skyfield sgp4

# %%
# 3. Run Training
# !python train.py
