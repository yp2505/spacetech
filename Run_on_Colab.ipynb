# %% [markdown]
# # SatRL 1-Million Step Cloud Training (Private GitHub Repo)
# This notebook clones/pulls your private GitHub repository in Google Colab using a Personal Access Token (PAT).

# %%
# 1. Fetch private GitHub repo using Personal Access Token (PAT)
import os, shutil
try:
    from google.colab import userdata
    GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')  # Set GITHUB_TOKEN in Colab Secrets (Key icon on left sidebar)
except Exception:
    GITHUB_TOKEN = 'YOUR_GITHUB_PERSONAL_ACCESS_TOKEN'  # Paste your github PAT here if not using Secrets

os.chdir('/content')
REPO_URL = f'https://{GITHUB_TOKEN}@github.com/yp2505/spacetech.git'
TARGET_DIR = '/content/spacetech'

# Remove non-git folder if leftover from old zip extraction
if os.path.exists(TARGET_DIR) and not os.path.exists(os.path.join(TARGET_DIR, '.git')):
    shutil.rmtree(TARGET_DIR)

# Clone repo if not present
if not os.path.exists(TARGET_DIR):
    # !git clone {REPO_URL} {TARGET_DIR}

# %cd {TARGET_DIR}
# !git reset --hard origin/main
# !git pull origin main
print("Current Directory:", os.getcwd())

# %%
# 2. Install Dependencies
# !pip install torch stable-baselines3 shimmy numpy matplotlib skyfield sgp4

# %%
# 3. Run Training
# !python train.py
